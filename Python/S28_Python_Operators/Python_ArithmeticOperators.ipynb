# %% [markdown]
# ## Python Operators

# %% [markdown]
# * In Python to carry out arithmetic or logical computation, we use special symbols called Operators.
# * The value that the operator operates on is called the operand.

# %% [markdown]
# #### Arithmetic Operators

# %%
from IPython.display import Image

# %%
Image('PythonArithmeticOperators.png')

# %% [markdown]
# ## Comparison Operators

# %%
Image('PythonComparisonOperators.png')

# %% [markdown]
# ## Logical Operators

# %%
Image('PythonLogicalOperators.png')

# %% [markdown]
# ## Bitwise Operators

# %%
Image('PythonBitwiseOperators.png')

# %% [markdown]
# ## Assignment Operators

# %%
Image('PythonAssignmentOperators.png')

# %% [markdown]
# ## Special Operators

# %%
# is
# is not

# %% [markdown]
# ## Membership Operators

# %%
# in
# not in
