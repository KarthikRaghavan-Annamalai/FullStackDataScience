# %% [markdown]
# # Normal Distribution

# %% [markdown]
# * Bell Curve
# * Normal Distribution / Gaussian Distribution
# * Most of the points lie in the middle
# * mean = median = mode

# %%
# Chcek the distribution of the features is an application of ND/GD

# %% [markdown]
# ## **Properties of Normal Distribution**
#
#
# * The mean = median = mode.
# * The normal curve is bell - shaped and symetric about the mean.
# * The total area under the curve is equal to one.
# * The normal curve approaches, but never touches the x-axis as it extends farther and farther away from the mean.

# %% [markdown]
# ## Skewed Distributions

# %%
from IPython.display import Image
Image('Skewness.png')

# %% [markdown]
# ## Central Limit Theorem

# %%
# CLT- If we have a dataset and if we select some samples and get mean, it is going to approach a normal distribution.

# %%
from numpy.random import seed
from numpy.random import randint
from numpy import mean

# %%
seed(1)


rolls = randint(1,7,100)

print(rolls)
# Out:
# [6 4 5 1 2 4 6 1 1 2 5 6 5 2 3 5 6 3 5 4 5 3 5 6 3 5 2 2 1 6 2 2 6 2 2 1 5
#  2 1 1 6 4 3 2 1 4 6 2 2 4 5 1 2 4 5 3 5 1 6 4 2 3 1 5 2 3 3 2 1 2 4 6 5 4
#  6 2 4 1 1 3 3 2 4 5 3 1 1 2 2 6 4 1 1 6 6 5 6 3 5 4]

# %%
import matplotlib.pyplot as plt


plt.hist(rolls)
# Out:
# (array([18.,  0., 22.,  0., 13.,  0., 14.,  0., 17., 16.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
means = [mean(randint(1,7,50)) for i in range(100)]

# %%
plt.hist(means)
# Out:
# (array([ 3.,  3.,  6.,  3., 15., 21., 19., 12., 11.,  7.]),
#  array([2.88, 2.99, 3.1 , 3.21, 3.32, 3.43, 3.54, 3.65, 3.76, 3.87, 3.98]),
#  <BarContainer object of 10 artists>)

# %%
means = [mean(randint(1,7,50)) for i in range(1000)]

# %%
plt.hist(means)
# Out:
# (array([ 14.,  27., 117., 160., 236., 220., 135.,  66.,  24.,   1.]),
#  array([2.82 , 2.962, 3.104, 3.246, 3.388, 3.53 , 3.672, 3.814, 3.956,
#         4.098, 4.24 ]),
#  <BarContainer object of 10 artists>)

# %%
means = [mean(randint(1,7,50)) for i in range(10000)]

# %%
plt.hist(means)
# Out:
# (array([   4.,   43.,  284., 1127., 2646., 2857., 1973.,  831.,  204.,
#           31.]),
#  array([2.52 , 2.704, 2.888, 3.072, 3.256, 3.44 , 3.624, 3.808, 3.992,
#         4.176, 4.36 ]),
#  <BarContainer object of 10 artists>)

# %%
means = [mean(randint(1,7,50)) for i in range(100000)]
plt.hist(means)
# Out:
# (array([2.1000e+01, 3.0800e+02, 3.3150e+03, 1.5456e+04, 2.9487e+04,
#         3.0201e+04, 1.6885e+04, 3.7530e+03, 5.4200e+02, 3.2000e+01]),
#  array([2.44, 2.65, 2.86, 3.07, 3.28, 3.49, 3.7 , 3.91, 4.12, 4.33, 4.54]),
#  <BarContainer object of 10 artists>)

# %%
means = [mean(randint(1,7,50)) for i in range(2000)]
plt.hist(means)
# Out:
# (array([ 13.,  29., 120., 277., 406., 445., 423., 198.,  73.,  16.]),
#  array([2.72 , 2.866, 3.012, 3.158, 3.304, 3.45 , 3.596, 3.742, 3.888,
#         4.034, 4.18 ]),
#  <BarContainer object of 10 artists>)
