# %% [markdown]
# # Data
#
# ## What is Data ?
#
# * Data is a collection of facts, such as numbers, words, measurements, observations or just descriptions of things.
#
# Practical examples of Data includes
#
# * Patient's records
# * Bank customer's records
# * Student's records
# * Social media activities
# * Sound from community, machinery or audio devices
# * Videos and images

# %% [markdown]
# ## Data types

# %%
from IPython.display import Image
Image('Datatypes.png')

# %% [markdown]
# #### Qualitative data (attribute)
#
# Qualitative data (commonly called attribute) contain values that express a quality, a state. They are mostly nonnumeric and can't be measured. Eg. Gender, color, feelings, etc.
#
# #### Quantitative data
#
# They are numerical in nature and can be measured. E.g. weight,
# distance, income, age, etc.

# %% [markdown]
# ## Qualitative data
#
# #### Nominal Variable
#
# variables cannot be easily ordered into hierachies, e.g we cannot say that black is greater than red.
#
# E.g: color, gender, etc.
#
# #### Ordinal variable
#
# It has all the properties of the Norminal  data and additiionally can be ordered and measured on a scale. differences between each one is not really known.
#
# For example, is the difference between “OK”
# and “Unhappy” the same as the difference between
# “Very Happy” and “Happy?”  We can’t say.
#
# E.g. good, better, best
#
# cold, warm, hot
#
# unsatisfied, satisfied, very satisfied

# %% [markdown]
# ## Quantitative data
#
# #### Interval
#
# Interval data are numeric scales in which we know both the order and the exact differences between the values.
#
# E.g measure of temperature, the difference between 60 and 50 degrees is a measurable 10 degrees, as is the difference between 80 and 70 degrees. <br>
# “Interval” itself means “space in between,” which is the important thing to remember interval scales not only tell us about order, but also about the value between each item.
#
# #### Ratio
#
# It is similiar to interval data , however, in order for data to be considered ratio data it must have a true zero, meaning it is not possible to have negative values in ratio data.
# An example of ratio data is measurements of height be that centimetres, metres, inches or feet.
# It is not possible to have a negative height. When comparing this to temperature it is easy to consider the difference between interval and ratio (which may be a little confusing at first!), as it is possible for the temperature to be -10 degrees, but nothing can be – 10 inches tall.

# %% [markdown]
# ## Quantitative data
#
# #### Discrete type
#
# can take only certain values, example; number of students enrolled in this course. This can be 1000, 2000, 3000 etc. students but definitely not 50.5 or 3000.75 students
#
# #### Continous type
#
# can take any value within a specific interval. Example; we can say he weighs 50.7 kg or the Temperature at this time is 11.12* celsius

# %% [markdown]
# **These are important to know because before building a machine learning model,
# you need to decide whether you are going to use a classification algorithm or you
# are going to use a regression algorithm. For instance, if your data contains a target
# which is continuous type then you choose a regression algorithm. If it is discrete or
# categorical then you may want to consider a classification algorithm.**

# %% [markdown]
# ## Data Attributes and Data Sources

# %% [markdown]
# #### Data Attributes
#
# * A data attribute is a characteristic of data that sets it apart from other data, such as location, length or type.
#
# * From data science point of view, they are the features of a dataset.
#
# For example, you have a sales dataset consisting of sales id, customer name, product purchased, quantity, unit price etc.
#
# Customer name, product purchased, quantity etc will be the attributes of that sales id

# %% [markdown]
# ## Data Sources
# #### Primary Data
#
# * Data that you collect by yourself or collected by the organisation conducting the research
#
# #### Secondary Data
#
# * Data thst you get from third - party sources such as givernment departments, Gartner, Mckinsley etc

# %% [markdown]
# ## Structured Vs unstructured Data

# %%
# https://www.ibm.com/cloud/blog/structured-vs-unstructured-data
